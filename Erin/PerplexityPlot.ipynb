# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
scores = pd.read_csv('perplexity_scores_50k.csv')

# %%
df = pd.DataFrame(scores)

# %%
fig = df.plot(x ='Topics', y='Perplexity', kind='line').get_figure()
