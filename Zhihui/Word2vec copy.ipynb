# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
import joblib
import pickle
import time
from copy import deepcopy
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV, GridSearchCV
from sklearn.decomposition import PCA
import xgboost as xgb
# Out:
# c:\Users\haile\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
#https://builtin.com/machine-learning/nlp-word2vec-python

# %%
df=pd.read_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/data_cleaned_1')
df.head()
# Out:
#    score                                               text
# 0    3.0  [good, helpfull, read, book, good, type, thats...
# 1    1.0  [sadly, overprice, irrelevant, spite, claim, i...
# 2    2.0  [endless, rant, howard, borrow, dennis, miller...
# 3    1.0  [not, quite, hip, really, shame, time, reserch...
# 4    5.0  [journey, centre, earth, hey, great, book, abs...

# %%
vector_size=100
#The number of dimensions of embeddings, the default is 100
window=3
#The maximum distance between a target word and its neighbours, default is 5
min_count=3
#The minimum counts of words in order for the word to be considered for the training of model, default is 5
workers=3
#The number of partitions during training, default is 3
sg=1
#The training algorithom, either CBOW(0) or skip gram(1), default is CBOW

#tokens = pd.Series(df['tokenized_text']).values
start_t = time.time()
w2vmodel=Word2Vec(df['text'],min_count=min_count,vector_size=vector_size,workers=workers,sg=sg)
print('Time taken to train word2vec model:' +str(time.time()-start_t))
# Out:
# Time taken to train word2vec model:27.78731656074524

# %%
filename='w2v_model1.joblib'
joblib.dump(w2vmodel,filename)
# Out:
# ['w2v_model1.joblib']

# %%
w2vmodel=joblib.load('w2v_model1.joblib')

# %%
word2vec_model_file = 'C:/Users/haile/OneDrive - University of Bristol/assessment2/data_cleaned_1' + 'word2vec_1' + '.model'
w2vmodel.save(word2vec_model_file)

# %%
w2v_model = Word2Vec.load(word2vec_model_file) #we have to save and load for some of the function below to work

# %%
w2v_model.wv.key_to_index
# Out:
# {'book': 0,
#  'not': 1,
#  'read': 2,
#  'one': 3,
#  'story': 4,
#  'quot': 5,
#  'like': 6,
#  'time': 7,
#  'would': 8,
#  'great': 9,
#  'make': 10,
#  'good': 11,
#  'write': 12,
#  'get': 13,
#  'well': 14,
#  'character': 15,
#  'love': 16,
#  'find': 17,
#  'life': 18,
#  'think': 19,
#  'the': 20,
#  'novel': 21,
#  'first': 22,
#  'many': 23,
#  'know': 24,
#  'much': 25,
#  'work': 26,
#  'people': 27,
#  'way': 28,
#  'also': 29,
#  'take': 30,
#  'even': 31,
#  'give': 32,
#  'year': 33,
#  'really': 34,
#  'could': 35,
#  'say': 36,
#  'author': 37,
#  'world': 38,
#  'see': 39,
#  'want': 40,
#  'end': 41,
#  'reader': 42,
#  'come': 43,
#  'best': 44,
#  'use': 45,
#  'thing': 46,
#  'go': 47,
#  'new': 48,
#  'look': 49,
#  'page': 50,
#  'little': 51,
#  'two': 52,
#  'never': 53,
#  'recommend': 54,
#  'seem': 55,
#  'man': 56,
#  'enjoy': 57,
#  'tell': 58,
#  'still': 59,
#  'ever': 60,
#  'old': 61,
#  'this': 62,
#  'child': 63,
#  'part': 64,
#  'must': 65,
#  'live': 66,
#  'feel': 67,
#  'start': 68,
#  'series': 69,
#  'and': 70,
#  'woman': 71,
#  'need': 72,
#  'day': 73,
#  'every': 74,
#  'back': 75,
#  'try': 76,
#  'put': 77,
#  'history': 78,
#  'help': 79,
#  'point': 80,
#  'long': 81,
#  'family': 82,
#  'however': 83,
#  'war': 84,
#  'another': 85,
#  'keep': 86,
#  'lot': 87,
#  'become': 88,
#  'understand': 89,
#  'may': 90,
#  'chapter': 91,
#  'young': 92,
#  'anyone': 93,
#  'though': 94,
#  'interest': 95,
#  'word': 96,
#  'review': 97,
#  'begin': 98,
#  'learn': 99,
#  'buy': 100,
#  'classic': 101,
#  'something': 102,
#  'plot': 103,
#  'real': 104,
#  'show': 105,
#  'excellent': 106,
#  'place': 107,
#  'do': 108,
#  'fact': 109,
#  'leave': 110,
#  'different': 111,
#  'bad': 112,
#  'right': 113,
#  'always': 114,
#  'friend': 115,
#  'human': 116,
#  'all': 117,
#  'yet': 118,
#  'wonderful': 119,
#  'without': 120,
#  'change': 121,
#  'mind': 122,
#  'experience': 123,
#  'american': 124,
#  'believe': 125,
#  'reading': 126,
#  'true': 127,
#  'easy': 128,
#  'school': 129,
#  'hard': 130,
#  'set': 131,
#  'idea': 132,
#  'detail': 133,
#  'god': 134,
#  'since': 135,
#  'happen': 136,
#  'turn': 137,
#  'last': 138,
#  'far': 139,
#  'star': 140,
#  'them': 141,
#  'include': 142,
#  'that': 143,
#  'quite': 144,
#  'mean': 145,
#  'person': 146,
#  'movie': 147,
#  'around': 148,
#  'enough': 149,
#  'call': 150,
#  'high': 151,
#  'age': 152,
#  'you': 153,
#  'follow': 154,
#  'name': 155,
#  'cover': 156,
#  'style': 157,
#  'almost': 158,
#  'writer': 159,
#  'highly': 160,
#  'information': 161,
#  'others': 162,
#  'problem': 163,
#  'although': 164,
#  'rather': 165,
#  'actually': 166,
#  'view': 167,
#  'might': 168,
#  'tale': 169,
#  'short': 170,
#  'nothing': 171,
#  'away': 172,
#  'favorite': 173,
#  'bit': 174,
#  'be': 175,
#  'men': 176,
#  'worth': 177,
#  'everyone': 178,
#  'three': 179,
#  'edition': 180,
#  'interesting': 181,
#  'reason': 182,
#  'society': 183,
#  'next': 184,
#  'everything': 185,
#  'fiction': 186,
#  'present': 187,
#  'sense': 188,
#  'action': 189,
#  'fun': 190,
#  'often': 191,
#  'big': 192,
#  'example': 193,
#  'especially': 194,
#  'but': 195,
#  'girl': 196,
#  'whole': 197,
#  'course': 198,
#  'him': 199,
#  'bring': 200,
#  'adventure': 201,
#  'there': 202,
#  'important': 203,
#  'question': 204,
#  'move': 205,
#  'lose': 206,
#  'fan': 207,
#  'today': 208,
#  'state': 209,
#  'second': 210,
#  'again': 211,
#  'father': 212,
#  'play': 213,
#  'main': 214,
#  'create': 215,
#  'provide': 216,
#  'let': 217,
#  'finish': 218,
#  'heart': 219,
#  'kind': 220,
#  'job': 221,
#  'home': 222,
#  'language': 223,
#  'truly': 224,
#  'order': 225,
#  'study': 226,
#  'several': 227,
#  'hand': 228,
#  'full': 229,
#  'self': 230,
#  'along': 231,
#  'century': 232,
#  'able': 233,
#  'death': 234,
#  'class': 235,
#  'beautiful': 236,
#  'probably': 237,
#  'someone': 238,
#  'event': 239,
#  'describe': 240,
#  'out': 241,
#  'sure': 242,
#  'felt': 243,
#  'early': 244,
#  'text': 245,
#  'lead': 246,
#  'down': 247,
#  'version': 248,
#  'line': 249,
#  'case': 250,
#  'thought': 251,
#  'deal': 252,
#  'small': 253,
#  'picture': 254,
#  'anything': 255,
#  'least': 256,
#  'simply': 257,
#  'mystery': 258,
#  'expect': 259,
#  'miss': 260,
#  'mother': 261,
#  'english': 262,
#  'less': 263,
#  'modern': 264,
#  'talk': 265,
#  'money': 266,
#  'student': 267,
#  'ago': 268,
#  'together': 269,
#  'subject': 270,
#  'pick': 271,
#  'power': 272,
#  'description': 273,
#  'perhaps': 274,
#  'boy': 275,
#  'meet': 276,
#  'past': 277,
#  'explain': 278,
#  'hope': 279,
#  'eye': 280,
#  'relationship': 281,
#  'kid': 282,
#  'literature': 283,
#  'later': 284,
#  'can': 285,
#  'john': 286,
#  'matter': 287,
#  'copy': 288,
#  'consider': 289,
#  'base': 290,
#  'science': 291,
#  'wish': 292,
#  'instead': 293,
#  'grow': 294,
#  'christian': 295,
#  'care': 296,
#  'open': 297,
#  'run': 298,
#  'fall': 299,
#  'force': 300,
#  'simple': 301,
#  'title': 302,
#  'historical': 303,
#  'pretty': 304,
#  'issue': 305,
#  'her': 306,
#  'kill': 307,
#  'interested': 308,
#  'side': 309,
#  'die': 310,
#  'perfect': 311,
#  'reference': 312,
#  'wait': 313,
#  'truth': 314,
#  'clear': 315,
#  'face': 316,
#  'note': 317,
#  'now': 318,
#  'hold': 319,
#  'personal': 320,
#  'finally': 321,
#  'guide': 322,
#  'funny': 323,
#  'black': 324,
#  'already': 325,
#  'original': 326,
#  'throughout': 327,
#  'wrong': 328,
#  'scene': 329,
#  'teach': 330,
#  'son': 331,
#  'daughter': 332,
#  'country': 333,
#  'romance': 334,
#  'more': 335,
#  'definitely': 336,
#  'fantasy': 337,
#  'house': 338,
#  'jane': 339,
#  'nature': 340,
#  'wonder': 341,
#  'add': 342,
#  'publish': 343,
#  'difficult': 344,
#  'art': 345,
#  'level': 346,
#  'parent': 347,
#  'form': 348,
#  'future': 349,
#  'for': 350,
#  'strong': 351,
#  'insight': 352,
#  'here': 353,
#  'etc': 354,
#  'realize': 355,
#  'social': 356,
#  'king': 357,
#  'continue': 358,
#  'else': 359,
#  'light': 360,
#  'maybe': 361,
#  'research': 362,
#  'certainly': 363,
#  'culture': 364,
#  'nice': 365,
#  'half': 366,
#  'wife': 367,
#  'middle': 368,
#  'lack': 369,
#  'free': 370,
#  'amaze': 371,
#  'sometimes': 372,
#  'mention': 373,
#  'hero': 374,
#  'close': 375,
#  'white': 376,
#  'bible': 377,
#  'list': 378,
#  'complete': 379,
#  'focus': 380,
#  'group': 381,
#  'america': 382,
#  'overall': 383,
#  'opinion': 384,
#  'too': 385,
#  'theme': 386,
#  'deep': 387,
#  'lord': 388,
#  'remember': 389,
#  'type': 390,
#  'ask': 391,
#  'section': 392,
#  'struggle': 393,
#  'piece': 394,
#  'offer': 395,
#  'stand': 396,
#  'quality': 397,
#  'account': 398,
#  'decide': 399,
#  'head': 400,
#  'number': 401,
#  'hear': 402,
#  'night': 403,
#  'stop': 404,
#  'sister': 405,
#  'attempt': 406,
#  'five': 407,
#  'return': 408,
#  'gift': 409,
#  'late': 410,
#  'upon': 411,
#  'four': 412,
#  'political': 413,
#  'within': 414,
#  'large': 415,
#  'happy': 416,
#  'plan': 417,
#  'purchase': 418,
#  'either': 419,
#  'earth': 420,
#  'collection': 421,
#  'guy': 422,
#  'result': 423,
#  'journey': 424,
#  'travel': 425,
#  'evil': 426,
#  'allow': 427,
#  'murder': 428,
#  'completely': 429,
#  'fine': 430,
#  'develop': 431,
#  'basic': 432,
#  'rest': 433,
#  'fill': 434,
#  'entire': 435,
#  'business': 436,
#  'dream': 437,
#  'save': 438,
#  'value': 439,
#  'entertain': 440,
#  'brother': 441,
#  'situation': 442,
#  'draw': 443,
#  'ring': 444,
#  'share': 445,
#  'city': 446,
#  'answer': 447,
#  'major': 448,
#  'dark': 449,
#  'theory': 450,
#  'general': 451,
#  'fascinate': 452,
#  'volume': 453,
#  'knowledge': 454,
#  'battle': 455,
#  'philosophy': 456,
#  'adult': 457,
#  'material': 458,
#  'period': 459,
#  'concept': 460,
#  'system': 461,
#  'rich': 462,
#  'perspective': 463,
#  'fight': 464,
#  'figure': 465,
#  'have': 466,
#  'appear': 467,
#  'enjoyable': 468,
#  'touch': 469,
#  'feeling': 470,
#  'library': 471,
#  'speak': 472,
#  'reviewer': 473,
#  'individual': 474,
#  'laugh': 475,
#  'non': 476,
#  'humor': 477,
#  'whether': 478,
#  'moment': 479,
#  'spend': 480,
#  'husband': 481,
#  'church': 482,
#  'step': 483,
#  'with': 484,
#  'term': 485,
#  'cause': 486,
#  'remain': 487,
#  'powerful': 488,
#  'introduction': 489,
#  'teacher': 490,
#  'sound': 491,
#  'depth': 492,
#  'couple': 493,
#  'relate': 494,
#  'sort': 495,
#  'poor': 496,
#  'stay': 497,
#  'extremely': 498,
#  'development': 499,
#  'yes': 500,
#  'absolutely': 501,
#  'soon': 502,
#  'surprise': 503,
#  'game': 504,
#  'what': 505,
#  'town': 506,
#  'agree': 507,
#  'attention': 508,
#  'bore': 509,
#  'involve': 510,
#  'various': 511,
#  'act': 512,
#  'religion': 513,
#  'behind': 514,
#  'law': 515,
#  'break': 516,
#  'topic': 517,
#  'land': 518,
#  'aspect': 519,
#  'clearly': 520,
#  'certain': 521,
#  'build': 522,
#  'third': 523,
#  'animal': 524,
#  'reality': 525,
#  'control': 526,
#  'condition': 527,
#  'among': 528,
#  'fast': 529,
#  'useful': 530,
#  'easily': 531,
#  'despite': 532,
#  'emotion': 533,
#  'across': 534,
#  'approach': 535,
#  'price': 536,
#  'twist': 537,
#  'suggest': 538,
#  'message': 539,
#  'about': 540,
#  'watch': 541,
#  'film': 542,
#  'effort': 543,
#  'george': 544,
#  'government': 545,
#  'top': 546,
#  'literary': 547,
#  'search': 548,
#  'discover': 549,
#  'particularly': 550,
#  'austen': 551,
#  'excite': 552,
#  'contain': 553,
#  'month': 554,
#  'amazon': 555,
#  'unique': 556,
#  'require': 557,
#  'master': 558,
#  'helpful': 559,
#  'appreciate': 560,
#  'saw': 561,
#  'claim': 562,
#  'forward': 563,
#  'ability': 564,
#  'please': 565,
#  'letter': 566,
#  'secret': 567,
#  'faith': 568,
#  'narrative': 569,
#  'possible': 570,
#  'process': 571,
#  'somewhat': 572,
#  'then': 573,
#  'alone': 574,
#  'pay': 575,
#  'challenge': 576,
#  'lesson': 577,
#  'beyond': 578,
#  'stuff': 579,
#  'source': 580,
#  'slow': 581,
#  'print': 582,
#  'brilliant': 583,
#  'bear': 584,
#  'dog': 585,
#  'choose': 586,
#  'choice': 587,
#  'whose': 588,
#  'role': 589,
#  'practice': 590,
#  'fantastic': 591,
#  'body': 592,
#  'serious': 593,
#  'date': 594,
#  'soul': 595,
#  'common': 596,
#  'kindle': 597,
#  'content': 598,
#  'receive': 599,
#  'rule': 600,
#  'fear': 601,
#  'quick': 602,
#  'dead': 603,
#  'capture': 604,
#  'particular': 605,
#  'hobbit': 606,
#  'single': 607,
#  'voice': 608,
#  'sad': 609,
#  'forget': 610,
#  'guess': 611,
#  'area': 612,
#  'sex': 613,
#  'color': 614,
#  'writing': 615,
#  'listen': 616,
#  'own': 617,
#  'complex': 618,
#  'week': 619,
#  'moral': 620,
#  'prose': 621,
#  'jesus': 622,
#  'college': 623,
#  'spirit': 624,
#  'marry': 625,
#  'which': 626,
#  'lewis': 627,
#  'crime': 628,
#  'illustration': 629,
#  'food': 630,
#  'catch': 631,
#  'hour': 632,
#  'fail': 633,
#  'quickly': 634,
#  'support': 635,
#  'regard': 636,
#  'indeed': 637,
#  'inspire': 638,
#  'exactly': 639,
#  'background': 640,
#  'design': 641,
#  'sit': 642,
#  'effect': 643,
#  'tolkien': 644,
#  'rise': 645,
#  'imagine': 646,
#  'beauty': 647,
#  'marriage': 648,
#  'island': 649,
#  'pass': 650,
#  'previous': 651,
#  'final': 652,
#  'compare': 653,
#  'engage': 654,
#  'religious': 655,
#  'mark': 656,
#  'seek': 657,
#  'conclusion': 658,
#  'other': 659,
#  'james': 660,
#  'doubt': 661,
#  'thank': 662,
#  'masterpiece': 663,
#  'serve': 664,
#  'totally': 665,
#  'member': 666,
#  'respect': 667,
#  'harry': 668,
#  'memory': 669,
#  'usually': 670,
#  'disappointed': 671,
#  'strange': 672,
#  'chance': 673,
#  'visit': 674,
#  'glad': 675,
#  'special': 676,
#  'magic': 677,
#  'test': 678,
#  'military': 679,
#  'due': 680,
#  'amp': 681,
#  'waste': 682,
#  'recipe': 683,
#  'reach': 684,
#  'check': 685,
#  'hate': 686,
#  'lie': 687,
#  'british': 688,
#  'desire': 689,
#  'exist': 690,
#  'available': 691,
#  'company': 692,
#  'england': 693,
#  'over': 694,
#  'field': 695,
#  'send': 696,
#  'trouble': 697,
#  'unfortunately': 698,
#  'program': 699,
#  'walk': 700,
#  'famous': 701,
#  'music': 702,
#  'conflict': 703,
#  'drive': 704,
#  'similar': 705,
#  'public': 706,
#  'lover': 707,
#  'advice': 708,
#  'suppose': 709,
#  'difference': 710,
#  'purpose': 711,
#  'race': 712,
#  'raise': 713,
#  'intrigue': 714,
#  'sentence': 715,
#  'thus': 716,
#  'suffer': 717,
#  'survive': 718,
#  'himself': 719,
#  'generation': 720,
#  'inside': 721,
#  'baby': 722,
#  'element': 723,
#  'treat': 724,
#  'concern': 725,
#  'dialogue': 726,
#  'genre': 727,
#  'before': 728,
#  'escape': 729,
#  'mostly': 730,
#  'trip': 731,
#  'image': 732,
#  'space': 733,
#  'red': 734,
#  'horror': 735,
#  'admit': 736,
#  'awesome': 737,
#  'ship': 738,
#  'western': 739,
#  'quote': 740,
#  'suspense': 741,
#  'pace': 742,
#  'spiritual': 743,
#  'discuss': 744,
#  'era': 745,
#  'paper': 746,
#  'addition': 747,
#  'translation': 748,
#  'party': 749,
#  'belief': 750,
#  'manage': 751,
#  'room': 752,
#  'nearly': 753,
#  'carry': 754,
#  'pain': 755,
#  'standard': 756,
#  'romantic': 757,
#  'eventually': 758,
#  'anne': 759,
#  'towards': 760,
#  'german': 761,
#  'incredible': 762,
#  'current': 763,
#  'amazing': 764,
#  'understanding': 765,
#  'analysis': 766,
#  'near': 767,
#  'win': 768,
#  'resource': 769,
#  'argument': 770,
#  'fit': 771,
#  'accept': 772,
#  'who': 773,
#  'comment': 774,
#  'community': 775,
#  'robert': 776,
#  'decision': 777,
#  'train': 778,
#  'reveal': 779,
#  'hop': 780,
#  'imagination': 781,
#  'christ': 782,
#  'discussion': 783,
#  'prove': 784,
#  'childhood': 785,
#  'low': 786,
#  'encounter': 787,
#  'except': 788,
#  'why': 789,
#  'service': 790,
#  'female': 791,
#  'personality': 792,
#  'none': 793,
#  'fire': 794,
#  'familiar': 795,
#  'disappoint': 796,
#  'evidence': 797,
#  'grade': 798,
#  'method': 799,
#  'realistic': 800,
#  'key': 801,
#  'explanation': 802,
#  'product': 803,
#  'huge': 804,
#  'hit': 805,
#  'hundred': 806,
#  'remind': 807,
#  'success': 808,
#  'influence': 809,
#  'cry': 810,
#  'recently': 811,
#  'smith': 812,
#  'emotional': 813,
#  'water': 814,
#  'produce': 815,
#  'amount': 816,
#  'introduce': 817,
#  'biography': 818,
#  'eat': 819,
#  'actual': 820,
#  'career': 821,
#  'french': 822,
#  'attack': 823,
#  'market': 824,
#  'itself': 825,
#  'lady': 826,
#  'explore': 827,
#  'off': 828,
#  'pull': 829,
#  'technique': 830,
#  'compel': 831,
#  'while': 832,
#  'sea': 833,
#  'cut': 834,
#  'jack': 835,
#  'boring': 836,
#  'mistake': 837,
#  'manner': 838,
#  'joy': 839,
#  'confuse': 840,
#  'summer': 841,
#  'fully': 842,
#  'sell': 843,
#  'local': 844,
#  'york': 845,
#  'popular': 846,
#  'ancient': 847,
#  'fly': 848,
#  'christmas': 849,
#  'structure': 850,
#  'politics': 851,
#  'pleasure': 852,
#  'tool': 853,
#  'trilogy': 854,
#  'from': 855,
#  'natural': 856,
#  'ten': 857,
#  'flaw': 858,
#  'paint': 859,
#  'charm': 860,
#  'honest': 861,
#  'practical': 862,
#  'obvious': 863,
#  'education': 864,
#  'gain': 865,
#  'henry': 866,
#  'feature': 867,
#  'david': 868,
#  'through': 869,
#  'leader': 870,
#  'beautifully': 871,
#  'heroine': 872,
#  'informative': 873,
#  'thriller': 874,
#  'freedom': 875,
#  'unlike': 876,
#  'horse': 877,
#  'post': 878,
#  'alive': 879,
#  'anti': 880,
#  'universe': 881,
#  'cross': 882,
#  'rand': 883,
#  'deserve': 884,
#  'when': 885,
#  'obviously': 886,
#  'tom': 887,
#  'west': 888,
#  'arrive': 889,
#  'passage': 890,
#  'technology': 891,
#  'project': 892,
#  'christianity': 893,
#  'thoroughly': 894,
#  'anyway': 895,
#  'south': 896,
#  'narrator': 897,
#  'skill': 898,
#  'mary': 899,
#  'essay': 900,
#  'center': 901,
#  'tragedy': 902,
#  'strength': 903,
#  'nation': 904,
#  'artist': 905,
#  'appeal': 906,
#  'civil': 907,
#  'cold': 908,
#  'recent': 909,
#  'road': 910,
#  'thanks': 911,
#  'model': 912,
#  'genius': 913,
#  'protagonist': 914,
#  'express': 915,
#  'outside': 916,
#  'poetry': 917,
#  'intelligent': 918,
#  'hat': 919,
#  'map': 920,
#  'throw': 921,
#  'error': 922,
#  'forever': 923,
#  'personally': 924,
#  'wild': 925,
#  'lay': 926,
#  'flow': 927,
#  'male': 928,
#  'position': 929,
#  'represent': 930,
#  'behavior': 931,
#  'loss': 932,
#  'paul': 933,
#  'likely': 934,
#  'record': 935,
#  'tradition': 936,
#  'indian': 937,
#  'ultimately': 938,
#  'principle': 939,
#  'brain': 940,
#  'destroy': 941,
#  'treasure': 942,
#  'soldier': 943,
#  'avoid': 944,
#  'toward': 945,
#  'emma': 946,
#  'professional': 947,
#  'how': 948,
#  'address': 949,
#  'doctor': 950,
#  'trust': 951,
#  'stick': 952,
#  'detailed': 953,
#  'six': 954,
#  'meaning': 955,
#  'cook': 956,
#  'longer': 957,
#  'essential': 958,
#  'typical': 959,
#  'scientific': 960,
#  'professor': 961,
#  'rate': 962,
#  'michael': 963,
#  'movement': 964,
#  'otherwise': 965,
#  'dickens': 966,
#  'fairly': 967,
#  'accurate': 968,
#  'apply': 969,
#  'intend': 970,
#  'catholic': 971,
#  'sequel': 972,
#  'basically': 973,
#  'wisdom': 974,
#  'negative': 975,
#  'foundation': 976,
#  'necessary': 977,
#  'format': 978,
#  'prejudice': 979,
#  'provoke': 980,
#  'peace': 981,
#  'humanity': 982,
#  'epic': 983,
#  'former': 984,
#  'army': 985,
#  'successful': 986,
#  'london': 987,
#  'lee': 988,
#  'deeply': 989,
#  'river': 990,
#  'peter': 991,
#  'cat': 992,
#  'usual': 993,
#  'minute': 994,
#  'positive': 995,
#  'notice': 996,
#  'car': 997,
#  'portrait': 998,
#  'passion': 999,
#  ...}

# %% [markdown]
# ### load pretrained model

# %%
from gensim.models import KeyedVectors

pretrained_path = "C:/Users/haile/OneDrive - University of Bristol/assessment2/glove_model2.txt"
model_2 = KeyedVectors.load_word2vec_format(pretrained_path, binary=False)
model_2.save('C:/Users/haile/OneDrive - University of Bristol/assessment2/glove_model.model')

# %%
#model = Word2Vec(vector_size=100, min_count=1)
w2v_model.build_vocab([list(model_2.index_to_key)], update=True)

# %%
training_examples_count = w2v_model.corpus_count
w2v_model.train(df['text'],total_examples=training_examples_count, epochs=w2v_model.epochs)
# Out:
# (18098531, 20081575)

# %% [markdown]
# https://towardsdatascience.com/word2vec-explained-49c52b4ccb71
#
# how to put the outputs of word2vec into data frame, and apply PCA on the outputs

# %%
emb_df = (
    pd.DataFrame(
        [w2v_model.wv.get_vector(str(n)) for n in w2vmodel.wv.key_to_index],
        index = w2vmodel.wv.key_to_index
    )
)
print(emb_df.shape)

emb_df.head()
# Out:
# (36738, 100)
#              0         1         2         3         4         5         6   \
# book   0.159897  0.446531  0.193733  0.171833 -0.168209  0.011781  0.194706
# not   -0.057648  0.376069  0.233399  0.049189 -0.053777 -0.251238  0.323133
# read  -0.083642  0.414169  0.327875  0.017268 -0.028621 -0.071050  0.355501
# one    0.071698  0.564244  0.085955  0.195965 -0.002936 -0.050000 -0.026133
# story -0.062988  0.274261 -0.095302  0.308135  0.229901  0.043316 -0.105754
#
#              7         8         9   ...        90        91        92  \
# book   0.306017 -0.362828 -0.302143  ...  0.015648  0.018295 -0.044424
# not    0.444645 -0.107316 -0.315226  ...  0.444007 -0.095590  0.015871
# read   0.293664 -0.410612 -0.506055  ...  0.201195 -0.241134  0.012516
# one    0.424163  0.070053 -0.429337  ...  0.128074  0.010254 -0.104710
# story  0.788721 -0.425252 -0.488860  ...  0.032930 -0.282237 -0.095458
#
#              93        94        95        96        97        98        99
# book  -0.140301  0.530423  0.179241 -0.105242  0.089344 -0.068826  0.224026
# not   -0.100124  0.351453  0.299043 -0.024236 -0.017444 -0.219344  0.059689
# read  -0.223860  0.319788  0.294548  0.127970  0.148626 -0.001360  0.055663
# one   -0.258344  0.571458  0.200598  0.199688 -0.164173  0.081466 -0.066718
# story -0.328511  0.079491 -0.107206  0.072664  0.341601 -0.076524  0.405122
#
# [5 rows x 100 columns]

# %%
print(w2v_model.wv.most_similar('wonderful'))
# Out:
# [('wonderfull', 0.8339987993240356), ('fabulous', 0.821222186088562), ('fantastic', 0.8117764592170715), ('splendid', 0.8047893643379211), ('amazing', 0.7656024098396301), ('terrific', 0.7541052103042603), ('nesbit', 0.7526402473449707), ('great', 0.7506873607635498), ('excellent', 0.744554340839386), ('gail', 0.744245171546936)]

# %%
print("Cosine similarity between 'wonderful' " +
               "terrible' - Skip Gram : ",
    w2v_model.wv.similarity('wonderful', 'bad'))
# Out:
# Cosine similarity between 'wonderful' terrible' - Skip Gram :  0.3421024

# %%
pca = PCA(n_components=2, random_state=7)
pca_mdl = pca.fit_transform(emb_df)

emb_df_PCA = (
    pd.DataFrame(
        pca_mdl,
        columns=['x','y'],
        index = emb_df.index
    )
)

plt.clf()
fig = plt.figure(figsize=(6,4))

plt.scatter(
    x = emb_df_PCA['x'],
    y = emb_df_PCA['y'],
    s = 0.4,
    color = 'maroon',
    alpha = 0.5
)

plt.xlabel('PCA-1')
plt.ylabel('PCA-2')
plt.title('PCA Visualization')
plt.plot()
# Out:
# []

# %%
# Function to map stars to sentiment
def map_sentiment(stars_received):
    if stars_received <= 2:
        return 0
    else:
        return 1
# Mapping stars to sentiment into three categories
df['sentiment'] = [ map_sentiment(x) for x in df['score']]
# Plotting the sentiment distribution
plt.figure()
pd.value_counts(df['sentiment']).plot.bar(title="Sentiment distribution in df")
plt.xlabel("Sentiment")
plt.ylabel("No. of rows in df")
plt.show()

# %%
def split_train_test(df, test_size=0.2, shuffle_state=True):
    X_train, X_test, Y_train, Y_test = train_test_split(df['text'], 
                                                        df['sentiment'], 
                                                        shuffle=shuffle_state,
                                                        test_size=test_size, 
                                                        random_state=15)
    print("Value counts for Train sentiments")
    print(Y_train.value_counts())
    print("Value counts for Test sentiments")
    print(Y_test.value_counts())
    print(type(X_train))
    print(type(Y_train))
    X_train = X_train.reset_index()
    X_test = X_test.reset_index()
    Y_train = Y_train.to_frame()
    Y_train = Y_train.reset_index()
    Y_test = Y_test.to_frame()
    Y_test = Y_test.reset_index()
    print(X_train.head())
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, y_train, y_test = split_train_test(df)
# Out:
# Value counts for Train sentiments
# 1    35376
# 0     4624
# Name: sentiment, dtype: int64
# Value counts for Test sentiments
# 1    8859
# 0    1141
# Name: sentiment, dtype: int64
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
#    index                                               text
# 0  45570  [multidimensional, thought, book, good, job, p...
# 1  21855  [magnetic, influence, success, business, find,...
# 2  41127  [read, weep, world, full, bad, book, write, am...
# 3   4849  [clear, channel, watt, book, great, show, book...
# 4  20742  [page, miss, line, mass, market, paperback, ed...

# %%
X_train.to_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/X_train')
X_test.to_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/X_test')
y_train.to_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/y_train')
y_test.to_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/y_test')

# %%
X_train=pd.read_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/X_train')
X_test=pd.read_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/X_test')
y_train=pd.read_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/y_train')
y_test=pd.read_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/y_test')

# %% [markdown]
# https://www.kaggle.com/code/varun08/sentiment-analysis-using-word2vec/notebook
#  define functions to calculate feature vectors

# %%
# Function to average all word vectors in a paragraph
def featureVecMethod(words, model, num_features):
    # Pre-initialising empty numpy array for speed
    featureVec = np.zeros(num_features,dtype="float32")
    nwords = 0
    
    #Converting Index2Word which is a list to a set for better speed in the execution.
    index2word_set = set(model.wv.index_to_key)
    for word in  words:
        if word in index2word_set:
            nwords = nwords + 1
            featureVec = np.add(featureVec,model.wv[word])
    
    if nwords ==0:
        featureVec = np.zeros(1000)
        #avoiding divide by zero, define it as a all zero vector
    else:
        featureVec = np.divide(featureVec, nwords)
    # Dividing the result by number of words to get average

    return featureVec

# %%
# Function for calculating the average feature vector
def getAvgFeatureVecs(reviews, model, num_features):
    counter = 0
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    for review in reviews:
        # Printing a status message every 1000th review
        if counter%1000 == 0:
            print("Comment %d of %d"%(counter,len(reviews)))
            
        reviewFeatureVecs[counter] = featureVecMethod(review, model, num_features)
            
        counter = counter+1
        
    return reviewFeatureVecs

# %%
trainDataVecs = getAvgFeatureVecs(X_train['text'], w2v_model, 1000)
# Out:
# Comment 0 of 40000
# Comment 1000 of 40000
# Comment 2000 of 40000
# Comment 3000 of 40000
# Comment 4000 of 40000
# Comment 5000 of 40000
# Comment 6000 of 40000
# Comment 7000 of 40000
# Comment 8000 of 40000
# Comment 9000 of 40000
# Comment 10000 of 40000
# Comment 11000 of 40000
# Comment 12000 of 40000
# Comment 13000 of 40000
# Comment 14000 of 40000
# Comment 15000 of 40000
# Comment 16000 of 40000
# Comment 17000 of 40000
# Comment 18000 of 40000
# Comment 19000 of 40000
# Comment 20000 of 40000
# Comment 21000 of 40000
# Comment 22000 of 40000
# Comment 23000 of 40000
# Comment 24000 of 40000
# Comment 25000 of 40000
# Comment 26000 of 40000
# Comment 27000 of 40000
# Comment 28000 of 40000
# Comment 29000 of 40000
# Comment 30000 of 40000
# Comment 31000 of 40000
# Comment 32000 of 40000
# Comment 33000 of 40000
# Comment 34000 of 40000
# Comment 35000 of 40000
# Comment 36000 of 40000
# Comment 37000 of 40000
# Comment 38000 of 40000
# Comment 39000 of 40000

# %%
trainDataVecs
# Out:
# array([[ 0.14034273, -0.02289204,  0.04288249, ..., -0.06831314,
#         -0.00203111, -0.01395326],
#        [ 0.12987085, -0.01425098,  0.05900474, ..., -0.04281596,
#         -0.00029992, -0.04611236],
#        [ 0.10155985, -0.01377982,  0.02490406, ..., -0.09436086,
#          0.03176169, -0.05752936],
#        ...,
#        [ 0.18298995, -0.0046916 , -0.03151794, ..., -0.08164315,
#          0.02932207, -0.01730692],
#        [ 0.16090125,  0.00254819,  0.01224033, ..., -0.11253697,
#          0.03710324, -0.03368711],
#        [ 0.18173517,  0.00423707, -0.03346983, ..., -0.11452925,
#          0.10254453, -0.01477751]], dtype=float32)

# %%
trainDataVecs.dump('C:/Users/haile/OneDrive - University of Bristol/assessment2/trainDataVecs')

# %%
trainDataVecs=pd.read_pickle('C:/Users/haile/OneDrive - University of Bristol/assessment2/trainDataVecs')

# %%
y_train.reset_index()
# Out:
#        level_0  index  sentiment
# 0            0  45570          1
# 1            1  21855          1
# 2            2  41127          0
# 3            3   4849          1
# 4            4  20742          0
# ...        ...    ...        ...
# 39995    39995  39296          1
# 39996    39996  49015          1
# 39997    39997   2693          1
# 39998    39998   8076          1
# 39999    39999   7624          1
#
# [40000 rows x 3 columns]

# %%
def remove_unuseful_rows(trainDataVecs,y_train):
    list=[]
    for i in range(trainDataVecs.shape[0]):
        if np.all(trainDataVecs[i,]==0):
            list.append(i)
    if len(list)!=0:
        trainDataVecs=np.delete(trainDataVecs,list,axis=0)
        y_train.drop(index=list,inplace=True)
    return trainDataVecs,y_train
# remove the sample with all zero vector and its corresponding y

# %%
trainDataVecs1,y_train1=remove_unuseful_rows(trainDataVecs,y_train)

# %%
y_train1.shape
# Out:
# (39999, 2)

# %%
trainDataVecs1.shape
# Out:
# (39999, 1000)

# %%
y_train1
# Out:
#        index  sentiment
# 0      45570          0
# 1      21855          0
# 2      41127          0
# 3       4849          0
# 4      20742          0
# ...      ...        ...
# 39995  39296          0
# 39996  49015          0
# 39997   2693          0
# 39998   8076          0
# 39999   7624          0
#
# [39999 rows x 2 columns]

# %%
y_train1=y_train1.reset_index(drop=True)

# %%
xgb_model = xgb.XGBClassifier(
    max_depth = 9, 
    min_child_weight = 1, 
    gamma = 0.4, 
    subsample=0.9, 
    colsample_bytree = 0.9,
    learning_rate =0.2,
    n_estimators=300)


start_time = time.time()
xgb_model.fit(trainDataVecs1, y_train1["sentiment"])
print("Time taken to fit the demodel with word2vec vectors: " + str(time.time() - start_time))
# Out:
# c:\Users\haile\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:02:37] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Time taken to fit the demodel with word2vec vectors: 396.1837809085846

# %% [markdown]
# https://xgboost.readthedocs.io/en/stable/python/python_api.html
# information about xgboost

# %%
filename='xgb_model1.joblib'
joblib.dump(xgb_model,filename)
# Out:
# ['xgb_model1.joblib']

# %%
xgb_model=joblib.load('xgb_model1.joblib')

# %% [markdown]
# ## Test data set

# %%
testDataVecs = getAvgFeatureVecs(X_test['text'], w2v_model, 1000)
# Out:
# Comment 0 of 10000
# Comment 1000 of 10000
# Comment 2000 of 10000
# Comment 3000 of 10000
# Comment 4000 of 10000
# Comment 5000 of 10000
# Comment 6000 of 10000
# Comment 7000 of 10000
# Comment 8000 of 10000
# Comment 9000 of 10000

# %%
y_test=y_test.reset_index(drop=True)

# %%
y_test.head()
# Out:
#    index  sentiment
# 0  35514          0
# 1  11006          0
# 2  13463          0
# 3  48119          0
# 4  36625          0

# %%
testDataVecs1,y_test1=remove_unuseful_rows(testDataVecs,y_test)

# %%
forest_prediction=forest.predict(testDataVecs1)

# %%
xgb_prediction=xgb_model.predict(testDataVecs1)

# %%
np.dot(forest_prediction-y_test1['sentiment'],forest_prediction-y_test1['sentiment'])
# Out:
# 1534

# %%
np.dot(xgb_prediction-y_test1['sentiment'],xgb_prediction-y_test1['sentiment'])
# Out:
# 827

# %%
print(classification_report(y_test['sentiment'],forest_prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10272\3643762021.py in <module>
# ----> 1 print(classification_report(y_test['sentiment'],forest_prediction))
#
# NameError: name 'forest_prediction' is not defined

# %%
print(classification_report(y_test['sentiment'],xgb_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.42      0.54      1141
#            1       0.93      0.98      0.95      8859
#
#     accuracy                           0.92     10000
#    macro avg       0.84      0.70      0.75     10000
# weighted avg       0.91      0.92      0.91     10000

# %%
y_pred = [x[1] for x in forest.predict_proba(testDataVecs1)]
fpr, tpr, thresholds = roc_curve(y_test['sentiment'], y_pred, pos_label = 1)

roc_auc = auc(fpr, tpr)

plt.figure(1, figsize = (5, 3))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
y_pred = [x[1] for x in xgb_model.predict_proba(testDataVecs1)]
fpr, tpr, thresholds = roc_curve(y_test['sentiment'], y_pred, pos_label = 1)

roc_auc = auc(fpr, tpr)

plt.figure(1, figsize = (5, 3))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Grid Test
#
# https://www.kaggle.com/code/tilii7/hyperparameter-grid-search-with-xgboost

# %%
#params = deepcopy(default_params)

param_grid = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [5,7,9,11],
        'learning_rate': [0.2,0.05]
        }

# %%
estimator = xgb.XGBClassifier(n_estimators=300, objective='binary:logistic')

# %%
trainDataVecs1.shape
# Out:
# (39999, 1000)

# %%
y_train1['sentiment'].values
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %%
eval_set = [(trainDataVecs1,y_train1['sentiment'].values)]
model = GridSearchCV(estimator=estimator, param_grid=param_grid, cv=3, scoring="neg_log_loss")

start_time = time.time()

model.fit(trainDataVecs1,y_train1['sentiment'].values, verbose=0)

print("Time taken for random search: " + str(time.time() - start_time))

# %%
model.dump('Data\grid_search')

# %%
model=pd.read_pickle('Data\grid_search')

# %%
print(model.best_params_)

# %% [markdown]
# # Doc2Vec

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(X_train['text'])]
print(documents[1])

# %%
start_t = time.time()
doc2vec_model = Doc2Vec(documents, vector_size=1000, window=3, min_count=1, workers=4)
print('Time taken to train word2vec model:' +str(time.time()-start_t))

# %%
filename='d2v_model.joblib'
joblib.dump(doc2vec_model,filename)

# %%
vector = doc2vec_model.infer_vector(X_train['text'][0])
print(len(vector))
print("Top 10 values in Doc2Vec inferred vector:")
print(vector[:10])

# %%
doc2vec_df = pd.read_csv(doc2vec_filename)

# %%
clf_decision_doc2vec = DecisionTreeClassifier()
# Fit the model
clf_decision_doc2vec.fit(doc2vec_df, y_train['score'])

# %% [markdown]
# https://www.kaggle.com/code/nitin194/twitter-sentiment-analysis-word2vec-doc2vec
